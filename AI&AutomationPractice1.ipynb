# %% [markdown]
# <a href="https://colab.research.google.com/github/kingsleynwafor54/RemoteSkillHub_Python/blob/main/AI%26AutomationPractice1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 🧮 Beginner Python Mini Projects

These are simple yet fun Python projects to practice your basics:
1. **Simple Calculator**
2. **Number Guessing Game**
3. **To-Do List Manager**

---

## ⚙️ 1. Simple Calculator

Let’s create a calculator that can perform **addition, subtraction, multiplication, and division**.

```python
# Simple Calculator

def calculator():
    print("Select operation:")
    print("1. Add")
    print("2. Subtract")
    print("3. Multiply")
    print("4. Divide")

    choice = input("Enter choice (1/2/3/4): ")

    num1 = float(input("Enter first number: "))
    num2 = float(input("Enter second number: "))

    if choice == '1':
        print(f"The result is: {num1 + num2}")
    elif choice == '2':
        print(f"The result is: {num1 - num2}")
    elif choice == '3':
        print(f"The result is: {num1 * num2}")
    elif choice == '4':
        if num2 != 0:
            print(f"The result is: {num1 / num2}")
        else:
            print("Error: Cannot divide by zero.")
    else:
        print("Invalid input!")

calculator()
✅ Try it: Run and choose an operation (1–4).

🎯 2. Number Guessing Game
The computer picks a random number, and you try to guess it!


import random

def guessing_game():
    number_to_guess = random.randint(1, 20)
    attempts = 0

    print("I'm thinking of a number between 1 and 20.")

    while True:
        guess = int(input("Take a guess: "))
        attempts += 1

        if guess < number_to_guess:
            print("Too low! Try again.")
        elif guess > number_to_guess:
            print("Too high! Try again.")
        else:
            print(f"🎉 Congratulations! You guessed it in {attempts} tries.")
            break

guessing_game()
✅ Try it: See how many attempts it takes you to win!

📝 3. To-Do List Manager
A simple text-based task manager that lets you add, view, and remove tasks.


todo_list = []

def show_menu():
    print("\n--- To-Do List Menu ---")
    print("1. Add Task")
    print("2. View Tasks")
    print("3. Remove Task")
    print("4. Exit")

def add_task():
    task = input("Enter a new task: ")
    todo_list.append(task)
    print(f"✅ Task '{task}' added!")

def view_tasks():
    if not todo_list:
        print("No tasks yet!")
    else:
        print("\nYour Tasks:")
        for i, task in enumerate(todo_list, start=1):
            print(f"{i}. {task}")

def remove_task():
    view_tasks()
    try:
        task_num = int(input("Enter task number to remove: "))
        removed = todo_list.pop(task_num - 1)
        print(f"❌ Task '{removed}' removed.")
    except (IndexError, ValueError):
        print("Invalid input. Please try again.")

def main():
    while True:
        show_menu()
        choice = input("Choose an option (1-4): ")

        if choice == '1':
            add_task()
        elif choice == '2':
            view_tasks()
        elif choice == '3':
            remove_task()
        elif choice == '4':
            print("Goodbye! 👋")
            break
        else:
            print("Invalid choice. Please enter a number between 1 and 4.")

main()
✅ Try it: Add, view, and remove your daily tasks!

# %% [markdown]
# # 🧠 Python Practice Assignment (Level 2)
# Welcome to your next Python challenge set!
# Each question will test your understanding of logic, loops, conditionals, and functions.
# 💡 **Instructions:**
# - Read each question carefully.
# - Write your code solution below each section in a new code cell.
# - Try the **Bonus Challenges** after completing the main task.
#
# ---
#
# ## 🎮 Question 1: Tic-Tac-Toe (2 Player Game)
#
# ### Objective:
# Create a console-based Tic-Tac-Toe game for **two players (X and O)**.
#
# ### Requirements:
# 1. Display a 3x3 game board.
# 2. Allow players to take turns choosing a position (row and column).
# 3. Check for a winner after every move.
# 4. Display “It’s a tie!” if all boxes are filled and no one wins.
#
# ### Example Output:
# X | O | X
# O | X |
# | | O
# 🎉 Player X wins!
#
# yaml
# Copy code
#
# ### Bonus Challenge:
# - Add input validation (prevent overwriting a filled cell).
# - Let players choose custom symbols instead of X and O.
#
# ---
#
# ## 🔁 Question 2: Palindrome Checker
#
# ### Objective:
# Check whether a given word or phrase is a **palindrome**.
#
# ### Requirements:
# 1. Ask the user to enter a word or phrase.
# 2. Ignore spaces and capitalization.
# 3. Print `"It's a palindrome!"` or `"Not a palindrome."`.
#
# ### Example Input:
# Enter a word: Racecar
#
# shell
# Copy code
# ### Example Output:
# ✅ It's a palindrome!
#
# markdown
# Copy code
#
# ### Bonus Challenge:
# - Extend it to check sentences like *“A man a plan a canal Panama”*.
# - Print the reversed string as part of the output.
#
# ---
#
# ## 🧮 Question 3: Factorial Calculator
#
# ### Objective:
# Calculate the **factorial** of a given number using **recursion** or **loops**.
#
# ### Requirements:
# 1. Ask the user for a number.
# 2. Compute its factorial (e.g. 5! = 120).
# 3. Display the result.
#
# ### Example:
# Enter a number: 5
# Output: The factorial of 5 is 120
#
# yaml
# Copy code
#
# ### Bonus Challenge:
# - Show each multiplication step (e.g. `5 x 4 x 3 x 2 x 1 = 120`).
# - Handle invalid inputs (like negative numbers).
#
# ---
#
# ## 🔢 Question 4: Fibonacci Sequence Generator
#
# ### Objective:
# Generate the first **n terms** of the Fibonacci sequence.
#
# ### Requirements:
# 1. Ask the user for how many terms to generate.
# 2. Print the sequence starting from 0 and 1.
#
# ### Example:
# Enter terms: 7
# Output: 0 1 1 2 3 5 8
#
# yaml
# Copy code
#
# ### Bonus Challenge:
# - Store the sequence in a list and print it neatly.
# - Find the **sum** of the generated sequence.
#
# ---
#
# ## 🔤 Question 5: Word Counter
#
# ### Objective:
# Count how many words are in a sentence.
#
# ### Requirements:
# 1. Ask the user to input a sentence.
# 2. Count the number of words separated by spaces.
# 3. Display the total count.
#
# ### Example:
# Input: "Python is fun to learn"
# Output: 5 words
#
# yaml
# Copy code
#
# ### Bonus Challenge:
# - Count how many **unique words** there are.
# - Ignore punctuation marks like commas and periods.
#
# ---
#
# ## 🏁 Submission Instructions
#
# ✅ **Task:** Solve all 5 questions in separate code cells.
# 🕒 **Deadline:** (Add your date here)
# 📩 **Submit:** Upload your Colab notebook or share the link.
#
# ---
#
# ### 💬 Reflection Questions (Optional)
# - Which task challenged you the most, and why?
# - How did you debug or test your code?
# - What would you improve if you had more time?
#
# ---
#
# 🎓 **Keep practicing — logic building is the foundation of becoming a great Python programmer!**
